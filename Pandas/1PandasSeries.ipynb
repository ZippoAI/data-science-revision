# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']

my_list = [10,20,30]

my_array = np.array([10,20,30])

d = {1:10, 2:20, 3:30}

# %%
arr = pd.Series(data= my_list, index=labels)

arr
# Out:
# a    10
# b    20
# c    30
# dtype: int64
