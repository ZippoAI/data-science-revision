# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a data frame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 41],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)

df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   41    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

labels = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=labels)

df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selection and indexing of columns

# %%
## Selecting columns

df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
## Selecting two columns

df2[['Name', 'Salary']]
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# ## Creating new columns

# %%
df2['Designation'] = ['Doctor', 'Engineer', 'Teacher', 'Pilot']

df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000     Teacher
# 3  Linda   42    London   85000       Pilot

# %% [markdown]
# ## How to remove a column

# %%
df2.drop('Designation', axis=1, inplace=True) # use inplace true to save it

df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3 = df2

df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3 = df3.drop('Name', axis=1)

df3
# Out:
#    Age      City  Salary
# 0   28  New York   65000
# 1   34     Paris   70000
# 2   29    Berlin   62000
# 3   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selecting a row

# %%
df4 = df2

# %%
df4.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df4.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# ## Selecting subsets of Rows and Columns

# %%
df3
# Out:
#    Age      City  Salary
# 0   28  New York   65000
# 1   34     Paris   70000
# 2   29    Berlin   62000
# 3   42    London   85000

# %%
df3.loc[[0,1]][['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df3.loc[[2,3]][['Name', 'Age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df3.loc[[2,3]][['Name', 'Age']]
#
# File c:\Users\iamre\Desktop\AI-ML-ENV\env\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\iamre\Desktop\AI-ML-ENV\env\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\iamre\Desktop\AI-ML-ENV\env\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Name'] not in index"

# %% [markdown]
# ## Conditional Selection

# %%
## I only want to see those people whose age is above 30
print('Above 30- ', )
df2[df['Age']>30]
# Out:
# Below 30-
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
print('Below 30- ')
df2[df2['Age']<30]
# Out:
# Below 30-
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000

# %%
print('Above 30 and city must be paris- ')
df2[(df2['Age']>30) & (df2['City']=='Paris')]
# Out:
# Above 30 and city must be paris-
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
