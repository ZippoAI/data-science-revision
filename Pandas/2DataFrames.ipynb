# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a data frame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 41],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)

df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   41    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

labels = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=labels)

df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selection and indexing of columns

# %%
## Selecting columns

df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
## Selecting two columns

df2[['Name', 'Salary']]
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# ## Creating new columns

# %%
df2['Designation'] = ['Doctor', 'Engineer', 'Teacher', 'Pilot']

df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000     Teacher
# 3  Linda   42    London   85000       Pilot

# %% [markdown]
# ## How to remove a column

# %%
df2.drop('Designation', axis=1, inplace=True) # use inplace true to save it

df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3 = df2

df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3 = df3.drop('Name', axis=1)

df3
# Out:
#    Age      City  Salary
# 0   28  New York   65000
# 1   34     Paris   70000
# 2   29    Berlin   62000
# 3   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selecting a row

# %%
df4 = df2

# %%
df4.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df4.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df4.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# ## Selecting subsets of Rows and Columns

# %%
df3
# Out:
#    Age      City  Salary
# 0   28  New York   65000
# 1   34     Paris   70000
# 2   29    Berlin   62000
# 3   42    London   85000

# %%
df3.loc[[0,1]][['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df4.loc[[2,3]][['Name', 'Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ## Conditional Selection

# %%
## I only want to see those people whose age is above 30
print('Above 30- ', )
df2[df['Age']>30]
# Out:
# Below 30-
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
print('Below 30- ')
df2[df2['Age']<30]
# Out:
# Below 30-
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 2  Peter   29    Berlin   62000

# %%
print('Above 30 and city must be paris- ')
df2[(df2['Age']>30) & (df2['City']=='Paris')]
# Out:
# Above 30 and city must be paris-
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   41    London   85000

# %%
data = {
    'Employee_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Name': ['John', 'Anna', 'Peter', 'Linda', 'David', 'Sophia', 'Michael', 'Emma'],
    'Age': [28, 34, 29, 41, 25, 31, 38, 27],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Department': [
        'IT', 'HR', 'Finance', 'Marketing',
        'IT', 'Sales', 'Finance', 'HR'
    ],
    'Position': [
        'Developer', 'HR Manager', 'Accountant', 'Marketing Manager',
        'Data Analyst', 'Sales Executive', 'Financial Analyst', 'Recruiter'
    ],
    'City': [
        'New York', 'Paris', 'Berlin', 'London',
        'Tokyo', 'Sydney', 'Toronto', 'Dubai'
    ],
    'Country': [
        'USA', 'France', 'Germany', 'UK',
        'Japan', 'Australia', 'Canada', 'UAE'
    ],
    'Experience_Years': [4, 8, 5, 12, 2, 6, 10, 3],
    'Salary': [65000, 70000, 62000, 85000, 58000, 68000, 92000, 60000],
    'Performance_Score': [88, 92, 79, 95, 84, 90, 97, 81],
    'Bonus': [5000, 7000, 4000, 10000, 3000, 6000, 12000, 3500],
    'Remote': [True, False, True, False, True, False, True, False],
    'Joining_Year': [2021, 2017, 2020, 2013, 2023, 2019, 2015, 2022]
}


new_df = pd.DataFrame(data)

new_df
# Out:
#    Employee_ID     Name  Age  Gender Department           Position      City  \
# 0          101     John   28    Male         IT          Developer  New York
# 1          102     Anna   34  Female         HR         HR Manager     Paris
# 2          103    Peter   29    Male    Finance         Accountant    Berlin
# 3          104    Linda   41  Female  Marketing  Marketing Manager    London
# 4          105    David   25    Male         IT       Data Analyst     Tokyo
# 5          106   Sophia   31  Female      Sales    Sales Executive    Sydney
# 6          107  Michael   38    Male    Finance  Financial Analyst   Toronto
# 7          108     Emma   27  Female         HR          Recruiter     Dubai
#
#      Country  Experience_Years  Salary  Performance_Score  Bonus  Remote  \
# 0        USA                 4   65000                 88   5000    True
# 1     France                 8   70000                 92   7000   False
# ...

# %%
new_df[(new_df['Experience_Years']>=4)&(new_df['Salary']>70000)]
# Out:
#    Employee_ID     Name  Age  Gender Department           Position     City  \
# 3          104    Linda   41  Female  Marketing  Marketing Manager   London
# 6          107  Michael   38    Male    Finance  Financial Analyst  Toronto
#
#   Country  Experience_Years  Salary  Performance_Score  Bonus  Remote  \
# 3      UK                12   85000                 95  10000   False
# 6  Canada                10   92000                 97  12000    True
#
#    Joining_Year
# 3          2013
# 6          2015
