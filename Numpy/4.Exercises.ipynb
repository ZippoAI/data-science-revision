# %%
import numpy as np

# %%
# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],  # Student 1
    [19, 92, 88],  # Student 2
    [17, 76, 95],  # Student 3
    [18, 65, 70],  # Student 4
    [20, 90, 85]   # Student 5
])

# %% [markdown]
# ## Valid Sudoku

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],

    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],

    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
b = np.sum(s,axis=1)
b
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
b==45
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
for i in b:
    if i == 45:
        print('Valid for rows') 
        
    else:
        print('Invalid for rows')
# Out:
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows
# Valid for rows

# %%
b = np.sum(s,axis=0)
count = 0
for i in b:
    
    if i == 45:
        print(f'Columns:{count} Valid for columns') 
        count+=1
        
        
    else:
        print(f'Columns:{count} Invalid for columns')
        count+=1
# Out:
# Columns:0 Valid for columns
# Columns:1 Valid for columns
# Columns:2 Valid for columns
# Columns:3 Valid for columns
# Columns:4 Valid for columns
# Columns:5 Valid for columns
# Columns:6 Valid for columns
# Columns:7 Valid for columns
# Columns:8 Valid for columns

# %%
t = s[:3,:3].sum()
t
# Out:
# np.int64(45)

# %%
t = s[:3,3:6].sum()
t
# Out:
# np.int64(45)

# %%
t = s[:3,6:9].sum()
t
# Out:
# np.int64(45)

# %%
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %%
for i in range(0,9,3):
    for j in range(0,9,3):
        print(s[i:i+3])
# Out:
# [[5 3 4 6 7 8 9 1 2]
#  [6 7 2 1 9 5 3 4 8]
#  [1 9 8 3 4 2 5 6 7]]
# [[5 3 4 6 7 8 9 1 2]
#  [6 7 2 1 9 5 3 4 8]
#  [1 9 8 3 4 2 5 6 7]]
# [[5 3 4 6 7 8 9 1 2]
#  [6 7 2 1 9 5 3 4 8]
#  [1 9 8 3 4 2 5 6 7]]
# [[8 5 9 7 6 1 4 2 3]
#  [4 2 6 8 5 3 7 9 1]
#  [7 1 3 9 2 4 8 5 6]]
# [[8 5 9 7 6 1 4 2 3]
#  [4 2 6 8 5 3 7 9 1]
#  [7 1 3 9 2 4 8 5 6]]
# [[8 5 9 7 6 1 4 2 3]
#  [4 2 6 8 5 3 7 9 1]
#  [7 1 3 9 2 4 8 5 6]]
# [[9 6 1 5 3 7 2 8 4]
#  [2 8 7 4 1 9 6 3 5]
#  [3 4 5 2 8 6 1 7 9]]
# [[9 6 1 5 3 7 2 8 4]
#  [2 8 7 4 1 9 6 3 5]
#  [3 4 5 2 8 6 1 7 9]]
# [[9 6 1 5 3 7 2 8 4]
#  [2 8 7 4 1 9 6 3 5]
#  [3 4 5 2 8 6 1 7 9]]

# %% [markdown]
# ## General Questions

# %%
# Columns: [Age, Math Marks, Science Marks]
df = np.array([
    [18, 85, 78],  # Student 1
    [19, 92, 88],  # Student 2
    [17, 76, 95],  # Student 3
    [18, 65, 70],  # Student 4
    [20, 90, 85]   # Student 5
])

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# ## Find the average age of students

# %%
average_age = np.mean(df[:,0])

print(f'Average age: {average_age}')
# Out:
# Average age: 18.4

# %% [markdown]
# # Extract math marks of all students

# %%
df
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
math_marks = df[:, 1]

print('All math marks: ',math_marks)
# Out:
# All math marks:  [85 92 76 65 90]

# %% [markdown]
# ## Find the highest science mark.

# %%
highest_science_mark = np.max(df[:, 2])

print('Highest Science Mark: ', highest_science_mark)
# Out:
# Highest Science Mark:  95

# %% [markdown]
# # Get the fetails of the student who scored more than 90 in math

# %%
above_90 = df[df[:, 1] > 90]

above_90
# Out:
# array([[19, 92, 88]])

# %%
rows = np.where(df[:, 1] > 90)
print(rows)
df[rows]
# Out:
# (array([1]),)
# array([[19, 92, 88]])

# %% [markdown]
# ## Increase the marks of all student by  5

# %%
df
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
df[:,1] = df[:,1]+5

df
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %% [markdown]
# ## Find how many students are younger than 19

# %%
row = df[df[:, 0] < 19]

print('Total: ', row.shape[0])
print('Total: ', row.shape[0])
# Out:
# Total:  3
# Total:  3

# %% [markdown]
# ## Find the average marks in each subject (column-wise mean).

# %%
df
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %%
np.mean(df[:, 1:], axis=0)
# Out:
# array([86.6, 83.2])

# %% [markdown]
# ## Get data of students who scored at least 80 in both subjects

# %%
df
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %%
df[(df[:, 1]>=80) & (df[:,2])]
# Out:
# array([[18, 90, 78],
#        [18, 90, 78],
#        [19, 97, 88],
#        [18, 90, 78],
#        [19, 97, 88]])

# %% [markdown]
# ## Replace all science mark less then 75 with 0

# %%
df
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %%
df[:,2][df[:,2] <75] = 0

df
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70,  0],
#        [20, 95, 85]])
