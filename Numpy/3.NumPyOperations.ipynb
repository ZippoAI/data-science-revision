# %%
import numpy as np

# %% [markdown]
# ## arithmetic operation

# %%
a1 = np.arange(1,6)
a2 = np.arange(6,11)

# %%
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
a2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
a1+a2
# Out:
# array([ 7,  9, 11, 13, 15])
