# %%
import numpy as np

# %% [markdown]
# ### Basic Array Creation

# %%
arr = np.array([1,2,3,4])

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
l = [[1,2,3],[4,5,6],[7,8,9]]

np.array(l)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
